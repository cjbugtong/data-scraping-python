# %%
# Import BeautifulSoup for reading and parsing HTML
from bs4 import BeautifulSoup
# Import requests to send HTTP requests to the website
import requests

# %%
# Website link that we want to scrape
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_Philippines'

# %%
# Send a request to the website
page = requests.get(url)
# Add headers to make the request look like it came from a real browser
# Some websites block requests without a user-agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0'
    # you can change it if you want to
}
# Send another request with headers included
page = requests.get(url, headers=headers)
# Convert the website content into a BeautifulSoup object
# This allows us to search and extract HTML elements easily
soup = BeautifulSoup(page.content, 'html')

# %%
# Print the entire HTML structure of the page
# Useful for checking the website structure while scraping
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available skin-theme-clientpref-thumb-standard" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of largest companies in the Philippines - Wikipedia
#   </title>
#   <script>
# ...

# %%
# Find the first table in the webpage
soup.find('table')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue<br/><small>(USD millions)</small>
# </th>
# <th>Profits<br/><small>(USD millions)</small>
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/San_Miguel_Corporation" title="San Miguel Corporation">San Miguel Corporation</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">26,024
# </td>
# <td style="text-align:center;">4
# </td>
# <td style="text-align:center;">53,184
# </td>
# <td><a href="/wiki/Mandaluyong" title="Mandaluyong">Mandaluyong</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a href="/wiki/SM_Investments" title="SM Investments">SM Investments</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">10,277
# </td>
# <td style="text-align:center;">1,385
# </td>
# <td style="text-align:center;">72,770
# </td>
# <td><a href="/wiki/Pasay" title="Pasay">Pasay</a>
# ...

# %%
# Find a specific table with the class name "wikitable sortable"
# This helps target the exact table we want
soup.find('table', class_='wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue<br/><small>(USD millions)</small>
# </th>
# <th>Profits<br/><small>(USD millions)</small>
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/San_Miguel_Corporation" title="San Miguel Corporation">San Miguel Corporation</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">26,024
# </td>
# <td style="text-align:center;">4
# </td>
# <td style="text-align:center;">53,184
# </td>
# <td><a href="/wiki/Mandaluyong" title="Mandaluyong">Mandaluyong</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a href="/wiki/SM_Investments" title="SM Investments">SM Investments</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">10,277
# </td>
# <td style="text-align:center;">1,385
# </td>
# <td style="text-align:center;">72,770
# </td>
# <td><a href="/wiki/Pasay" title="Pasay">Pasay</a>
# ...

# %%
# Get all tables from the page and select the first one
table = soup.find_all('table')[0]

# %%
# Print the selected table
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue<br/><small>(USD millions)</small>
# </th>
# <th>Profits<br/><small>(USD millions)</small>
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/San_Miguel_Corporation" title="San Miguel Corporation">San Miguel Corporation</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">26,024
# </td>
# <td style="text-align:center;">4
# </td>
# <td style="text-align:center;">53,184
# </td>
# <td><a href="/wiki/Mandaluyong" title="Mandaluyong">Mandaluyong</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a href="/wiki/SM_Investments" title="SM Investments">SM Investments</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">10,277
# </td>
# <td style="text-align:center;">1,385
# </td>
# <td style="text-align:center;">72,770
# </td>
# <td><a href="/wiki/Pasay" title="Pasay">Pasay</a>
# ...

# %%
# Find all table header cells (<th>)
# These are usually the column names
ph_company_titles = table.find_all('th')

# %%
# Print all headers
print(ph_company_titles)
# Out:
# [<th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue<br/><small>(USD millions)</small>
# </th>, <th>Profits<br/><small>(USD millions)</small>
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>]

# %%
# Clean the text inside each header
# strip() removes extra spaces and line breaks
ph_table_titles =[title.text.strip() for title in ph_company_titles]

# %%
# Print cleaned column names
print(ph_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue(USD millions)', 'Profits(USD millions)', 'Employees', 'Headquarters']

# %%
# Check the data type
type(ph_table_titles)
# Out:
# list

# %%
# Import pandas for handling tabular data
import pandas as pd

# %%
# Create an empty DataFrame using the scraped column names
df = pd.DataFrame(columns = ph_table_titles)
# Display empty DataFrame
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue(USD millions), Profits(USD millions), Employees, Headquarters]
# Index: []

# %%
# Find all rows inside the table
column_data = table.find_all('tr')

# %%
# Loop through each row except the header row
for row in column_data[1:]:
    # Find all table data cells (<td>) inside the row
    row_data = row.find_all('td')
    # Clean each cell value using strip()
    individual_row_data =[data.text.strip() for data in row_data]
    # Get current length of DataFrame
    # This will be used as the new row index
    length = len(df)
    # Insert scraped row data into the DataFrame
    df.loc[length]= individual_row_data

# %%
# Display the completed DataFrame
df
# Out:
#    Rank                                       Name            Industry  \
# 0     1                     San Miguel Corporation        Conglomerate
# 1     2                             SM Investments        Conglomerate
# 2     3                            Manila Electric           Utilities
# 3     4                         JG Summit Holdings        Conglomerate
# 4     5                               Banco de Oro             Banking
# 5     6                    Aboitiz Equity Ventures        Conglomerate
# 6     7                          Ayala Corporation        Conglomerate
# 7     8                                 GT Capital        Conglomerate
# 8     9                 Jollibee Foods Corporation         Restaurants
# 9    10                              Cosco Capital        Conglomerate
# 10   11                                       PLDT  Telecommunications
# 11   12                            Alliance Global        Conglomerate
# ...

# %%
# Export the DataFrame into a CSV file
# index=False removes the default index column in the CSV
df.to_csv(r'C:\Users\PC\Desktop\Data Analytics\Python\Outputs_here\Top_Company_PH.csv', index = False)
